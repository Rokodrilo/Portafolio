# %% [markdown]
# # 🔊🎤 Transcribe el audio que necesites!
#
# ## 🙀 Gratamente Sorprendido!

# %% [markdown]
# En el mundo de la inteligencia artificial el 2022 fue sin duda el momento de marcar muchos hitos, en este caso les hablaré de Whisper.
#
# Whisper es un modelo de reconocimiento de voz desarrollado por OpenAI que ha demostrado ser altamente efectivo en el procesamiento del lenguaje hablado. Este modelo de propósito general está entrenado en un conjunto de datos grande y diverso para ofrecer una amplia gama de capacidades. Además del reconocimiento de voz multilingüe, Whisper también puede realizar traducción de voz e identificación del idioma.
#
# El uso de conjuntos de datos grandes y diversos permite a Whisper manejar una amplia variedad de acentos y dialectos con precisión. Además, su capacidad para realizar múltiples tareas lo convierte en una herramienta valiosa para la comunicación global y la investigación lingüística.
#
# En resumen, Whisper es un modelo innovador en el campo del reconocimiento de voz que ofrece una amplia gama de capacidades gracias a su entrenamiento en conjuntos de datos grandes y diversos. Su capacidad para manejar múltiples idiomas y tareas lo convierte en una herramienta valiosa tanto para la comunicación como para la investigación.

# %% [markdown]
# Para los entendidos en el tema les pareserá algo tonto mi "Asombro", ya sé que no es otra cosa que una red neuronal de tipo transformer(si un tipo de red que existe desde el 2017), básicamente es esto:

# %% [markdown]
# ![whisper.png](data:image/png;base64,...)

# %% [markdown]
# Mi asombro está en  lo sencillo de su uso (si, se que es sencillo porque ya está entrenada que es la parte dura😅😂)en que el entrenamiento de esta red se hizo con 680.000 ¡¡¡ 77 años !!! horas de audio con su correspondiente texto en multiples idiomas!!!!!
#
# Aca podrán encontrar más información:
#
# ► Whisper (Blog post)
# https://openai.com/blog/whisper/
#
# ► Whisper (GitHub)
# https://github.com/openai/whisper
#
#
# Vamos a ponernos manos a la obra y veras lo fácil que es!

# %% [markdown]
# ## 🛠️ 1. Instalamos lo que requerimos

# %%
# !pip install git+https://github.com/openai/whisper.git
# !pip install jiwer
#En este caso no vamos a traducir audios a ingles, se puede hacer y lo podes consultar 
    en el repositorio que les he dejado ...

# %% [markdown]
# ## 📝 2. Transcribimos!

# %% [markdown]
# Si deseamos hacer la transcripción dentro de Python usaremos:

# %%
import whisper

model = whisper.load_model("base")
result = model.transcribe("audio.mp3")
print(result["text"])

# %% [markdown]
# Si queremos un archivo con la transcripción usaremos:

# %%
# !whisper "/content/audio.mp3" --task transcribe --model medium --verbose False --output_dir audio_transcription

# 🚩 🚨 Recuerda cambiar la ruta y nombre de tu audio, es recomendable tener GPU o hacer la transcripción
#en google colab con la Aceleración por hardware con GPU en "Entorno de ejecución" > "Cambiar tipo de entorno de ejecución"
